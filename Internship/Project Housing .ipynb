# %%
import pandas as pd
import numpy as  np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\admin\Downloads\Project-Housing_splitted\train.csv")
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df.loc[df['SalePrice']== " "]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
np.mean(df["LotFrontage"])
# Out:
# 70.98846960167715

# %%
df["LotFrontage"]= df["LotFrontage"].fillna(np.mean(df["LotFrontage"]))

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
df_visual_nominal=df[['MSZoning','Street','Alley','LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive','MiscFeature', 'SaleType', 'SaleCondition']].copy()

# %%
df_visual_nominal.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
import seaborn as sns

# %%
ax=sns.countplot(x='MSZoning',data=df_visual_nominal)
print(df_visual_nominal['MSZoning'].value_counts())
# Out:
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64

# %%
ax=sns.countplot(x='BldgType',data=df_visual_nominal)
print(df_visual_nominal['BldgType'].value_counts())
# Out:
# 1Fam      981
# TwnhsE     90
# Duplex     41
# Twnhs      29
# 2fmCon     27
# Name: BldgType, dtype: int64

# %%
ax=sns.countplot(x='HouseStyle',data=df_visual_nominal)
print(df_visual_nominal['HouseStyle'].value_counts())
# Out:
# 1Story    578
# 2Story    361
# 1.5Fin    121
# SLvl       47
# SFoyer     32
# 1.5Unf     12
# 2.5Unf     10
# 2.5Fin      7
# Name: HouseStyle, dtype: int64

# %%
ax=sns.countplot(x='Foundation',data=df_visual_nominal)
print(df_visual_nominal['Foundation'].value_counts())
# Out:
# CBlock    516
# PConc     513
# BrkTil    112
# Slab       21
# Stone       5
# Wood        1
# Name: Foundation, dtype: int64

# %%
ax=sns.countplot(x='Functional',data=df_visual_nominal)
print(df_visual_nominal['Functional'].value_counts())
# Out:
# Typ     1085
# Min2      30
# Min1      25
# Mod       12
# Maj1      11
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64

# %%
ax=sns.countplot(x='GarageType',data=df_visual_nominal)
print(df_visual_nominal['GarageType'].value_counts())
# Out:
# Attchd     691
# Detchd     314
# BuiltIn     70
# Basment     16
# CarPort      8
# 2Types       5
# Name: GarageType, dtype: int64

# %%
ax=sns.countplot(x='PavedDrive',data=df_visual_nominal)
print(df_visual_nominal['PavedDrive'].value_counts())
# Out:
# Y    1071
# N      74
# P      23
# Name: PavedDrive, dtype: int64

# %%
ax=sns.countplot(x='SaleType',data=df_visual_nominal)
print(df_visual_nominal['SaleType'].value_counts())
# Out:
# WD       999
# New      106
# COD       38
# ConLD      8
# ConLI      5
# ConLw      4
# Oth        3
# CWD        3
# Con        2
# Name: SaleType, dtype: int64

# %%
ax=sns.countplot(x='SaleCondition',data=df_visual_nominal)
print(df_visual_nominal['SaleCondition'].value_counts())
# Out:
# Normal     945
# Partial    108
# Abnorml     81
# Family      18
# Alloca      12
# AdjLand      4
# Name: SaleCondition, dtype: int64

# %%
df_visual_ordinal=df[['SaleCondition','YrSold']].copy()

# %%
sns.catplot(x='SaleCondition',y='YrSold',data=df)

# %%
sns.catplot(x='SaleCondition',y='SaleType',data=df)

# %%
df_visual_continuous=df[["LotArea","SalePrice"]].copy()

# %%
sns.displot(df_visual_continuous['SalePrice'],kde=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
enc= OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     127         120       3.0     70.98847     4928     1.0    NaN
# 1     889          20       3.0     95.00000    15865     1.0    NaN
# 2     793          60       3.0     92.00000     9920     1.0    NaN
# 3     110          20       3.0    105.00000    11751     1.0    NaN
# 4     422          20       3.0     70.98847    16635     1.0    NaN
# ...   ...         ...       ...          ...      ...     ...    ...
# 1163  289          20       3.0     70.98847     9819     1.0    NaN
# 1164  554          20       3.0     67.00000     8777     1.0    NaN
# 1165  196         160       3.0     24.00000     2280     1.0    NaN
# 1166   31          70       0.0     50.00000     8500     1.0    1.0
# 1167  617          60       3.0     70.98847     7861     1.0    NaN
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1168.000000  1168.000000  1168.000000  1168.000000    1168.000000
# mean    724.136130    56.767979     3.013699    70.988470   10484.749144
# std     416.159877    41.940650     0.633120    22.437056    8957.442311
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     360.500000    20.000000     3.000000    60.000000    7621.500000
# 50%     714.500000    50.000000     3.000000    70.988470    9522.500000
# 75%    1079.500000    70.000000     3.000000    79.250000   11515.500000
# max    1460.000000   190.000000     4.000000   313.000000  164660.000000
#
#             Street      Alley     LotShape  LandContour  Utilities  ...  \
# count  1168.000000  77.000000  1168.000000  1168.000000     1168.0  ...
# mean      0.996575   0.467532     1.938356     2.773973        0.0  ...
# std       0.058445   0.502217     1.412262     0.710027        0.0  ...
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.9,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
df.corr()['SalePrice'].sort_values()
# Out:
# ExterQual      -0.624820
# BsmtQual       -0.620256
# PoolQC         -0.595229
# KitchenQual    -0.592468
# GarageFinish   -0.512794
#                   ...
# GarageCars      0.628329
# GrLivArea       0.707300
# OverallQual     0.789185
# SalePrice       1.000000
# Utilities            NaN
# Name: SalePrice, Length: 81, dtype: float64

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.7,linecolor='black',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
df.corr()['SalePrice'].sort_values(ascending=False).drop(['SalePrice']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %%
df.skew()
# Out:
# Id                0.026526
# MSSubClass        1.422019
# MSZoning         -1.796785
# LotFrontage       2.710383
# LotArea          10.659285
#                    ...
# MoSold            0.220979
# YrSold            0.115765
# SaleType         -3.660513
# SaleCondition    -2.671829
# SalePrice         1.953878
# Length: 81, dtype: float64

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning         float64
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType         float64
# SaleCondition    float64
# SalePrice          int64
# Length: 81, dtype: object

# %%
df['LotFrontage'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['LotFrontage'].unique()
# Out:
# array([ 70.9884696,  95.       ,  92.       , 105.       ,  58.       ,
#         88.       ,  70.       ,  80.       ,  50.       ,  44.       ,
#        129.       ,  59.       ,  55.       ,  64.       ,  24.       ,
#         68.       ,  71.       ,  74.       ,  61.       ,  60.       ,
#        120.       ,  84.       , 141.       ,  30.       ,  65.       ,
#         76.       , 100.       ,  85.       ,  75.       , 107.       ,
#        122.       ,  82.       ,  62.       ,  73.       ,  79.       ,
#         77.       ,  41.       ,  69.       ,  90.       ,  96.       ,
#         72.       ,  34.       ,  78.       ,  63.       ,  40.       ,
#         98.       , 160.       , 108.       , 128.       ,  51.       ,
#         81.       ,  99.       ,  66.       ,  37.       , 174.       ,
#         87.       ,  53.       , 152.       ,  47.       ,  86.       ,
#         56.       ,  89.       ,  35.       ,  52.       ,  21.       ,
# ...

# %%
df['GarageCars'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['GrLivArea'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['GrLivArea'].unique()
# Out:
# array([ 958, 2217, 2013, 1844, 1602, 1863, 1392, 1803, 1214, 1216, 1376,
#        1829, 1560, 1065, 1393, 1502,  816, 1232, 1113, 1302, 1792,  768,
#        1078, 1050, 1200, 2259, 1416, 1856, 1048, 1660, 1752, 1389, 2620,
#        1382, 2320,  969, 1370, 2158,  912,  935, 1656,  928, 1709,  985,
#        1800, 1122,  334, 1269, 2792,  438, 1306,  930, 1795, 2207, 1923,
#         951,  827,  900, 1132, 1982,  925, 2224, 1316,  874, 2515, 1194,
#        1640, 1496,  754, 1165,  774, 1718,  803, 2076, 1494, 1498, 1285,
#        1734, 1426,  986, 1040, 1456, 1252, 1539, 2263, 1099, 1593, 1968,
#        2020, 1144, 1053, 1665, 1652,  936, 1786, 3608, 2184,  864, 1986,
#        1554, 1993, 1314, 1564, 1824, 1839, 1080, 1088, 1842, 1646,  872,
#        1336, 1406, 1442, 1846, 1355, 1196,  894, 1574, 1801, 1641, 2153,
#        1319, 2035,  882, 1478, 2290, 2612, 4476, 1707, 1717, 1052, 1518,
#        1262,  964, 1728,  784, 1287, 2599, 1537, 1536,  904, 1265, 1505,
# ...

# %%
df['SaleCondition'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['SaleCondition'].unique()
# Out:
# array([4., 5., 0., 3., 2., 1.])

# %%
df.shape
# Out:
# (1168, 81)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([   1,    1,    1, ..., 1166, 1166, 1166], dtype=int64),
#  array([11, 22, 36, ..., 28, 41, 65], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# ...

# %%
df_new_z.shape
# Out:
# (0, 81)

# %%
features=df.drop("SalePrice",axis=1)
target=df["SalePrice"]

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
for i in range(0,50):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train,target_train)
    pred_train=lr.predict(features_train)
    pred_test= lr.predict(features_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
#       1 for i in range(0,50):
#       2     features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
# ----> 3     lr.fit(features_train,target_train)
#       4     pred_train=lr.predict(features_train)
#       5     pred_test= lr.predict(features_test)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=12)

# %%
lr.fit(features_train,target_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 lr.fit(features_train,target_train)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File D:\Anaconda\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# ...

# %%
pred_test=lr.predict(features_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 pred_test=lr.predict(features_test)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:345, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
#     343     check_is_fitted(self)
# --> 345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
print(r2_score(target_test,pred_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 print(r2_score(target_test,pred_test))
#
# NameError: name 'pred_test' is not defined
