# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.naukri.com/") # open webpage on automated chrome browser

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")# enter the designation
designation.send_keys('Data Analyst')
loc=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input") #  entering the location 
loc.send_keys('Bangalore')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit") # clicking the serach button 
search.click()

# %%
job_title=[]
job_loc=[]
company_name=[]
experience_required=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')# scrapping the job titles 
for i in title_tags[0:10]:
    job_title.append(i.text)
    
loc_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 locWdth"]')# scrapping the job locations
for i in loc_tags[0:10]:
    job_loc.append(i.text)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')# scrapping the company names 
for i in company_tags[0:10]:
    company_name.append(i.text)
    
exp_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 expwdth"]')# scrapping the company names 
for i in exp_tags[0:10]:
    experience_required.append(i.text)
    
df=pd.DataFrame({'Job_title':job_title,'Job_loc':job_loc,'Company_name':company_name,'Experience_required':experience_required})
df
# Out:
#                         Job_title                             Job_loc  \
# 0                    Data Analyst                 Bangalore/Bengaluru
# 1                    Data Analyst                 Bangalore/Bengaluru
# 2                    Data Analyst                 Bangalore/Bengaluru
# 3          Senior Data Analyst II                 Bangalore/Bengaluru
# 4            Project Data Analyst                 Bangalore/Bengaluru
# 5  Data Analyst, Business Analyst  Bangalore/Bengaluru(HSR Layout +1)
# 6                    Data Analyst     Temp. WFH - Bangalore/Bengaluru
# 7        Executive - Data Analyst                 Bangalore/Bengaluru
# 8                    Data Analyst                 Bangalore/Bengaluru
# 9                    Data Analyst                 Bangalore/Bengaluru
#
#                          Company_name Experience_required
# 0                       Shell Pvt Ltd             2-5 Yrs
# 1                       Shell Pvt Ltd             3-5 Yrs
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.naukri.com/") # open webpage on automated chrome browser
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")# enter the designation
designation.send_keys('Data Scientist')
loc=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input") #  entering the location 
loc.send_keys('Bangalore')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit") # clicking the serach button 
search.click()

# %%
job_title=[]
job_loc=[]
company_name=[]
experience_required=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')# scrapping the job titles 
for i in title_tags[0:10]:
    job_title.append(i.text)
    
loc_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 locWdth"]')# scrapping the job locations
for i in loc_tags[0:10]:
    job_loc.append(i.text)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')# scrapping the company names 
for i in company_tags[0:10]:
    company_name.append(i.text)
    
exp_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 expwdth"]')# scrapping the company names 
for i in exp_tags[0:10]:
    experience_required.append(i.text)
    
df=pd.DataFrame({'Job_title':job_title,'Job_loc':job_loc,'Company_name':company_name,'Experience_required':experience_required})
df
# Out:
#                                           Job_title  \
# 0                  Analystics & Modeling Specialist
# 1                                    Data Scientist
# 2                                    Data Scientist
# 3      Data & Analytics Lead, Geo Analytics - GAMMA
# 4                Weather and Climate Data Scientist
# 5                                    Data Scientist
# 6                               Data Scientist - II
# 7                             Senior Data Scientist
# 8                              Manager-Data Science
# 9  ACN - Applied Intelligence - Data Scientist - 09
#
#                                              Job_loc             Company_name  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...              Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune            Tech Mahindra
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.naukri.com/") # open webpage on automated chrome browser
designation=driver.find_element(By.CLASS_NAME,"suggestor-input ")# enter the designation
designation.send_keys('Data Scientist')
loc=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input") #  entering the location 
loc.send_keys('Delhi/NCR')
search=driver.find_element(By.CLASS_NAME,"qsbSubmit") # clicking the serach button 
search.click()

# %%
job_title=[]
job_loc=[]
company_name=[]
experience_required=[]

title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')# scrapping the job titles 
for i in title_tags[0:10]:
    job_title.append(i.text)
    
loc_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 locWdth"]')# scrapping the job locations
for i in loc_tags[0:10]:
    job_loc.append(i.text)
    
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')# scrapping the company names 
for i in company_tags[0:10]:
    company_name.append(i.text)
    
exp_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft fs12 lh16 expwdth"]')# scrapping the company names 
for i in exp_tags[0:10]:
    experience_required.append(i.text)
    
df=pd.DataFrame({'Job_title':job_title,'Job_loc':job_loc,'Company_name':company_name,'Experience_required':experience_required})
df
# Out:
#                                            Job_title  \
# 0                                     Data Scientist
# 1                                     Data Scientist
# 2                 Data Science - Engineering Manager
# 3                          Data Scientist - R/Python
# 4  Artificial Intelligence/Computer Vision Engine...
# 5             Data Scientist- Bangalore/ Pune Hybrid
# 6                  Associate Director - Data Science
# 7                  Data Scientist - Engine Algorithm
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                              Job_loc  \
# 0  Delhi / NCR, New Delhi, Hyderabad/Secunderabad...
# 1  Hybrid - Noida, Kolkata, Hyderabad/Secunderaba...
# 2                     New Delhi, Bangalore/Bengaluru
# 3  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 4  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 5             Delhi / NCR, Pune, Bangalore/Bengaluru
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.flipkart.com/") # open webpage on automated chrome browser
product=driver.find_element(By.CLASS_NAME,"_3704LK")# enter the product 
product.send_keys('Sunglasses')
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu") # clicking the search button 
search.click()

# %%
brand_name=[]
product_descp=[]
price=[]
discount=[]

brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')# scrapping the brand names 
for i in brand:
    brand_name.append(i.text)
description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')# scrapping the product description
for i in description:
    product_descp.append(i.text)
product_price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')# scrapping the brand prices
for i in product_price:
    price.append(i.text)
discount_rate=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')# scrapping the discount rate
for i in discount_rate:
    discount.append(i.text)
    
df1=pd.DataFrame({'Brand':brand_name,'Product description':product_descp,'Price':price,'Discount':discount})
df1
# Out:
#                 Brand                                Product description  \
# 0           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 1          LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 2            Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 3        Silver Kartz           UV Protection Clubmaster Sunglasses (53)
# 4            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 5            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 6          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 7              OCHILA              UV Protection Aviator Sunglasses (58)
# 8           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 9          LIZA ANGEL  UV Protection, Polarized Rectangular Sunglasse...
# 10      VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...
# 11       Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.flipkart.com/") # open webpage on automated chrome browser
phone=driver.find_element(By.CLASS_NAME,"_3704LK")# enter the mobile  
phone.send_keys('iphone 11')
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu") # clicking the search button 
search.click()

# %%
ratings=[]
summary=[]
review=[]

rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')# scrapping the phone ratings  
for i in rating:
    ratings.append(i.text)
review_summary=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')# scrapping the phone rating summary  
for i in review_summary:
    summary.append(i.text)
full_review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')# scrapping the phone full summary 
for i in full_review:
    review.append(i.text)
    
df2=pd.DataFrame({'Ratings':ratings,'Review summary':summary,'Full_review':review})
df2
# Out:
#   Ratings        Review summary  \
# 0       5             Fabulous!
# 1       5         Great product
# 2       5      Perfect product!
# 3       5              Terrific
# 4       5        Simply awesome
# 5       5        Simply awesome
# 6       4  Good quality product
# 7       5      Perfect product!
#
#                                          Full_review
# 0  Fast performance to previous iPhone x\nGood ca...
# 1           Awesome product ❤️❤️\nThank you Flipkart
# 2  After using 3 years mobile review. Excellent &...
# 3  I am using the phone for last 5 years and foun...
# 4  Really satisfied with the Product I received.....
# 5    Loving it , but the price is bitter and costly.
# 6  impressively Nice......\nOne of the greatest i...
# 7                         Nice products thanks flkat

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.flipkart.com/") # open webpage on automated chrome browser
product=driver.find_element(By.CLASS_NAME,"_3704LK")# enter the product 
product.send_keys('Sneakers')
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu") # clicking the search button 
search.click()

# %%
brand=[]
product_des=[]
price=[]
discount=[]

brand_name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')# scrapping the brand names  
for i in brand_name[0:38]:
    brand.append(i.text)
description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')# scrapping the product description
for i in description[0:38]:
    product_des.append(i.text)

prices=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')# scrapping the prices
for i in prices[0:38]:
    price.append(i.text)

brand_name=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')# scrapping the discount rate   
for i in brand_name[0:38]:
    brand.append(i.text)
    
    
df=pd.DataFrame({'Brand':brand,'Product_description':product_des,'Price':price,'Discount':discount})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 22>()
#      18 for i in brand_name[0:38]:
#      19     brand.append(i.text)
# ---> 22 df=pd.DataFrame({'Brand':brand,'Product_description':product_des,'Price':price,'Discount':discount})
#      23 df
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.amazon.in/") # open webpage on automated chrome browser
product=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute ")# enter the product 
product.send_keys('Laptop')
search=driver.find_element(By.CLASS_NAME,"nav-search-submit-text nav-sprite nav-progressive-attribute") # clicking the search button 
search.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [18], in <cell line: 4>()
#       2 driver
#       3 driver.get("https://www.amazon.in/") # open webpage on automated chrome browser
# ----> 4 product=driver.find_element(By.CLASS_NAME,"nav-input nav-progressive-attribute ")# enter the product
#       5 product.send_keys('Laptop')
#       6 search=driver.find_element(By.CLASS_NAME,"nav-search-submit-text nav-sprite nav-progressive-attribute") # clicking the search button
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
Titles=[]
Ratings=[]
Price=[]

title_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')# scrap the titles 
for i in title_tags[0:10]:
    Titles.append(i.text)
rating=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')# scrap the ratings 
for i in rating[0:10]:
    Ratings.append(i.text)
price=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')# scrap the prices
for i in price[0:10]:
    Price.append(i.text)
df=pd.DataFrame({'Title':title_tags,'Rating':rating,'Price':price})
df
# Out:
# Empty DataFrame
# Columns: [Title, Rating, Price]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.azquotes.com/") # open webpage on automated chrome browser
quote=driver.find_element(By.CLASS_NAME,"active ")# enter the
quote.send_keys('Top quotes')
search=driver.find_element(By.CLASS_NAME,"collapse") # clicking the search button 
search.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       3 driver.get("https://www.azquotes.com/") # open webpage on automated chrome browser
#       4 quote=driver.find_element(By.CLASS_NAME,"active ")# enter the
# ----> 5 quote.send_keys('Top quotes')
#       6 search=driver.find_element(By.CLASS_NAME,"collapse") # clicking the search button
#       7 search.click()
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:233, in WebElement.send_keys(self, *value)
#     230             remote_files.append(self._upload(file))
#     231         value = "\n".join(remote_files)
# --> 233 self._execute(
#     234     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     235 )
#
# ...

# %%
Quote=[]
Author=[]
Quote_type=[]

quote=driver.find_elements(By.XPATH,'//a[@class="title"]')# scrap the quotes
for i in quote:
    Quote.append(i.text)
author=driver.find_elements(By.XPATH,'//div[@class="author"]')# scrap the author names
for i in author:
    Author.append(i.text)
type=driver.find_elements(By.XPATH,'//div[@class="tags"]')# scrap the quote type
for i in type:
    Quote_type.append(i.text)
    
df=pd.DataFrame({'Quote':quote,'Author':author,'Quote_type':type})
df
# Out:
#                                                 Quote  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# 4   <selenium.webdriver.remote.webelement.WebEleme...
# ..                                                ...
# 95  <selenium.webdriver.remote.webelement.WebEleme...
# 96  <selenium.webdriver.remote.webelement.WebEleme...
# 97  <selenium.webdriver.remote.webelement.WebEleme...
# 98  <selenium.webdriver.remote.webelement.WebEleme...
# 99  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                                Author  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...
# 1   <selenium.webdriver.remote.webelement.WebEleme...
# 2   <selenium.webdriver.remote.webelement.WebEleme...
# 3   <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.jagranjosh.com/") # open webpage on automated chrome browser
topic=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a") #click on the GK topic 
topic.send_keys('GK')
title=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a ")# click the list of prime ministers 
title.send_keys('List of all prime ministers')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [28], in <cell line: 6>()
#       4 topic=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a") #click on the GK topic
#       5 topic.send_keys('GK')
# ----> 6 title=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a ")# click the list of prime ministers
#       7 title.send_keys('List of all prime ministers')
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
name=[]
date=[]
office_term=[]
remarks=[]

name_tag=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[2]/p/strong/a')# scrap the names 
for i in name_tag:
    name.append(i.text)
date_tag=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[3]/p')# scrap the dates
for i in date_tag:
    date.append(i.text)
office_tag=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[4]/p[1]/span')# scrap the office term 
for i in office_tag:
    office_term.append(i.text)
remark_tag=driver.find_elements(By.XPATH,'/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[2]/td[5]/p')# scrap the office term 
for i in remark_tag:
    remarks.append(i.text)
    
df2=pd.DataFrame({'Presidents_name':name_tag,'Born_dead':date_tag,'Tems_of_office':office_tag,'Remarks':remark_tag})
df2
# Out:
#                                      Presidents_name  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                            Born_dead  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                       Tems_of_office  \
# 0  <selenium.webdriver.remote.webelement.WebEleme...
#
#                                              Remarks
# 0  <selenium.webdriver.remote.webelement.WebEleme...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://www.motor1.com/") # open webpage on automated chrome browser
car_list=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a ")# click on the list option
car_list.send_keys('LIST')
title=driver.find_element(By.CLASS_NAME,"text-boxe") # clicking on the title  
title.send_keys('50 most expensive cars in the world')
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       3 driver.get("https://www.motor1.com/") # open webpage on automated chrome browser
#       4 car_list=driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[6]/ul/li[1]/a ")# click on the list option
# ----> 5 car_list.send_keys('LIST')
#       6 title=driver.find_element(By.CLASS_NAME,"text-boxe") # clicking on the title
#       7 title.send_keys('50 most expensive cars in the world')
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webelement.py:233, in WebElement.send_keys(self, *value)
#     230             remote_files.append(self._upload(file))
#     231         value = "\n".join(remote_files)
# --> 233 self._execute(
#     234     Command.SEND_KEYS_TO_ELEMENT, {"text": "".join(keys_to_typing(value)), "value": keys_to_typing(value)}
#     235 )
#
# ...

# %%
name=[]
desc=[]
price=[]

car_name=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/h3[1]/a')# scrap the names 
for i in car_name:
    name.append(i.text)
description=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p[5]')# scrap the description
for i in description:
    desc.append(i.text)
car_price=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/p[4]/strong')# scrap the prices 
for i in car_price:
    price.append(i.text)
    
df3=pd.DataFrame({'Names':car_name,'Description':description,'Prices':car_price})
df3
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       2 desc=[]
#       3 price=[]
# ----> 5 car_name=driver.find_elements(By.XPATH,'/html/body/div[3]/div[7]/div[2]/div[1]/div[2]/div[1]/h3[1]/a')# scrap the names
#       6 for i in car_name:
#       7     name.append(i.text)
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:892, in WebDriver.find_elements(self, by, value)
#     888     value = '[name="%s"]' % value
#     890 # Return empty list if driver returns null
#     891 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 892 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File D:\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
# ...
