# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver                    
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos") # open webpage on automated chrome browser

# %%
rank=[]
video_name=[]
artist=[]
views=[]
publication_date=[]

rank=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[1]')]
video_name=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[2]')]
artist=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[3]')]
views=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[4]')]
publication_date=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"][1]/tbody/tr/td[5]')]

df=pd.DataFrame({'Rank':rank,'Name':video_name,'Artist':artist,'Views':views,'Publication_date':publication_date})
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[4]
# 1    2.                                   "Despacito"[7]
# 2    3.                       "Johny Johny Yes Papa"[14]
# 3    4.                                  "Bath Song"[15]
# 4    5.                               "Shape of You"[16]
# 5    6.                              "See You Again"[18]
# 6    7.                "Phonics Song with Two Words"[23]
# 7    8.                                "Uptown Funk"[24]
# 8    9.                          "Wheels on the Bus"[25]
# 9   10.  "Learning Colors – Colorful Eggs on a Farm"[26]
# 10  11.                              "Gangnam Style"[27]
# 11  12.   "Masha and the Bear – Recipe for Disaster"[32]
# 12  13.                             "Dame Tu Cosita"[33]
# 13  14.                                      "Sugar"[34]
# 14  15.                                       "Roar"[35]
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.bcci.tv/")

# %%
ODI=driver.find_element(By.XPATH,'//*[@id="navigation"]/ul[1]/li[2]/a')
ODI.click()

# %%
Place = [i.text for i in driver.find_elements(By.XPATH,'//*[@id="fixtures"]/div[3]/div[1]/div[1]/div/div[4]/div')]
Match=[i.text for i in driver.find_elements(By.XPATH,'//*[@id="fixtures"]/div[3]/div[1]/div[1]/div/div[1]/h5[2]/span')]
Date_time=[i.text for i in driver.find_elements(By.XPATH,'//*[@id="fixtures"]/div[3]/div[1]/div[1]/div/div[1]/div')]
df=pd.DataFrame({'Place':Place,'Match':Match,'Date & Time':Date_time})
df
# Out:
#                                            Place  \
# 0  1st ODI - Barsapara Cricket Stadium, Guwahati
#
#                                         Match               Date & Time
# 0  SRI LANKA TOUR OF INDIA ODI SERIES 2022-23  10 JAN 2023\n1:30 PM IST

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.guru99.com/")

# %%
loc=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
loc.send_keys('Exceptions')
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]")
search.click()
Name=[i.text for i in driver.find_elements(By.XPATH,'//*[@id="post-1953"]/div/div/p[1]')]
Desc=[i.text for i in driver.find_elements(By.XPATH,'//*[@id="post-1953"]/div/div/p[1]')]

df=pd.DataFrame({'Name':Name,'Desc':Desc})
df
# Out:
# Empty DataFrame
# Columns: [Name, Desc]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.statisticstimes.com/")

# %%
rank=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[1]')]
state= [i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[2]')]
GSDP_1=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[3]')]
GSDP_2=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]')]
share=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[5]')]
GDP=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[6]')]

df=pd.DataFrame({'Rank':rank,'States':state,'Previous GSDP':GSDP_1,'Latest GSDP':GSDP_2,'Share':share,'GDP':GDP})
df
# Out:
#    Rank                     States Previous GSDP Latest GSDP   Share      GDP
# 0     1                Maharashtra             -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu     1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh     1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat             -   1,502,899   7.96%  228.290
# 4     5                  Karnataka     1,631,977   1,493,127   7.91%  226.806
# ..  ...                        ...           ...         ...     ...      ...
# 61   29                     Sikkim        28,391      25,141   0.15%   17,060
# 62   30                   Nagaland             -      24,534   0.15%        -
# 63   31          Arunachal Pradesh             -      22,488   0.13%        -
# 64   32                    Mizoram        24,424      20,947   0.13%   17,797
# 65   33  Andaman & Nicobar Islands             -           -       -        -
#
# [66 rows x 6 columns]

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://github.com/")

# %%
title=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="text-normal"]')] [:17]
descp=[i.text for i in driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')] [:17]
count=[i.text for i in driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')] [:17]
Lang=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')] [:17]

df=pd.DataFrame({'Title':title,'Description':descp,'Contributors':count,'Language used':Lang})
df
# Out:
#                  Title                                        Description  \
# 0             openai /       Examples and guides for using the OpenAI API
# 1          microsoft /  24 Lessons, 12 Weeks, Get Started as a Web Dev...
# 2           gragland /  A ChatGPT Chrome extension. Integrates ChatGPT...
# 3        Developer-Y /  List of Computer Science courses with video le...
# 4          JuanCrg90 /                        My notes of Clean Code book
# 5         sismo-core /        Contracts of the Sismo Attestation Protocol
# 6             google /  Tools for synching and streaming files from Wi...
# 7            jwasham /  A complete computer science study plan to beco...
# 8                1c7 /       👩🏿‍💻👨🏾‍💻👩🏼‍💻👨🏽‍💻👩🏻‍💻中国独立开发者项目列表 -- 分享大家都在做什么
# 9          microsoft /  Large-scale Self-supervised Pre-training Acros...
# 10  facebookresearch /  Code release for HyperReel: High-Fidelity 6-Do...
# 11     binhnguyennus /  The Patterns of Scalable, Reliable, and Perfor...
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.billboard.com/")

# %%
search=driver.find_element(By.XPATH,'//div[@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]')
search.click()

# %%
desc=[i.text for i in driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]')]

df=pd.DataFrame({'Description':desc})
df
# Out:
# Empty DataFrame
# Columns: [Description]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.naukri.com/hr-recruiters-consultants")

# %%
designation=driver.find_element(By.CLASS_NAME,"sugInp")
designation.send_keys('Data Science')
search=driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/div/form/div[1]/button")
search.click()

# %%
name=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')][:20]
dsgnt=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')][:20]
comp=[i.text for i in driver.find_elements(By.XPATH,'//a[@class="ellipsis"]')][:20]
skills=[i.text for i in driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')][:20]
loc=[i.text for i in driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')][:20]

df1=pd.DataFrame({'Name':name,'Designation':dsgnt,'Company':comp,'Skills':skills,'Location':loc})
df1
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                 Kalpana Dumpala
# 9                                         Mubarak
# 10                                 Kushal Rastogi
# 11                           Dr. S. Prasanna Devi
# 12                             Mahesh Babu Channa
# 13                             Vaishnavi Kudalkar
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                                  Avnish Mishra
# 17                                Sakshi Chhikara
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
book=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[2]')]
author=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[3]')]
volume_sold=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[4]')]
publ=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[5]')]
genre=[i.text for i in driver.find_elements(By.XPATH,'//table[@class="in-article sortable"][1]/tbody/tr/td[6]')]


df=pd.DataFrame({'Book':book,'Author':author,'Volume_sold':volume_sold,'Publisher':publ,'Genre':genre})
df
# Out:
#                                                  Book            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume_sold        Publisher                        Genre
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
name=[i.text for i in driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]')][:20]
year=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="lister-item-year text-muted unbold"]')][:20]
genre=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="genre"]')][:20]
runtime=[i.text for i in driver.find_elements(By.XPATH,'//span[@class="runtime"]')][:20]
rating=[i.text for i in driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')][:20]
vote=[i.text for i in driver.find_elements(By.XPATH,'//span[@name="nv"]')][:20]

df=pd.DataFrame({'Name':name,'Year_span':year,'Genre':genre,'Runtime ':runtime,'Ratings':rating,'Votes':vote})
df
# Out:
#                                       Name    Year_span  \
# 0           1. Game of Thrones (2011–2019)  (2011–2019)
# 1              2. Stranger Things (2016– )     (2016– )
# 2          3. The Walking Dead (2010–2022)  (2010–2022)
# 3            4. 13 Reasons Why (2017–2020)  (2017–2020)
# 4                   5. The 100 (2014–2020)  (2014–2020)
# 5   6. Orange Is the New Black (2013–2019)  (2013–2019)
# 6                    7. Riverdale (2017– )     (2017– )
# 7               8. Grey's Anatomy (2005– )     (2005– )
# 8                 9. The Flash (2014–2023)  (2014–2023)
# 9                    10. Arrow (2012–2020)  (2012–2020)
# 10             11. Money Heist (2017–2021)  (2017–2021)
# 11     12. The Big Bang Theory (2007–2019)  (2007–2019)
# 12            13. Black Mirror (2011–2019)  (2011–2019)
# 13                14. Sherlock (2010–2017)  (2010–2017)
# 14                 15. Vikings (2013–2020)  (2013–2020)
# 15     16. Pretty Little Liars (2010–2017)  (2010–2017)
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\admin\Downloads\chromedriver_win32.zip\chromedriver.exe")  # connect the driver 
driver 
driver.get("https://archive.ics.uci.edu/")

# %%
name=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[1]')]
data_type=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[2]')]
task=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[3]')]
attribute=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[4]')]
instance=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[5]')]
year=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr[2]/td[6]')]
            
df=pd.DataFrame({'Dataset_name':name,'Type':data_type,'Attribute':attribute,'Instance':instance,'Year':year})
df
# Out:
#   Dataset_name           Type                    Attribute Instance Year
# 0      Abalone  Multivariate   Categorical, Integer, Real     4177    8

# %%
Name=[]
name=[i.text for i in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]')]
name
# Out:
# ["622 Data Sets\nTable View  List View\nName\nData Types\nDefault Task\nAttribute Types\n# Instances\n# Attributes\nYear\n  Abalone\nMultivariate \nClassification \nCategorical, Integer, Real \n4177 \n8 \n1995 \n  Adult\nMultivariate \nClassification \nCategorical, Integer \n48842 \n14 \n1996 \n  Annealing\nMultivariate \nClassification \nCategorical, Integer, Real \n798 \n38 \n    Anonymous Microsoft Web Data\n  Recommender-Systems \nCategorical \n37711 \n294 \n1998 \n  Arrhythmia\nMultivariate \nClassification \nCategorical, Integer, Real \n452 \n279 \n1998 \n  Artificial Characters\nMultivariate \nClassification \nCategorical, Integer, Real \n6000 \n7 \n1992 \n  Audiology (Original)\nMultivariate \nClassification \nCategorical \n226 \n  1987 \n  Audiology (Standardized)\nMultivariate \nClassification \nCategorical \n226 \n69 \n1992 \n  Auto MPG\nMultivariate \nRegression \nCategorical, Real \n398 \n8 \n1993 \n  Automobile\nMultivariate \nRegression \nCategorical, Integer, Real \n2
# ...
